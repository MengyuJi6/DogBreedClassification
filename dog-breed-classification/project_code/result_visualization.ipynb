# %%
import matplotlib
import matplotlib.pyplot as plt
import csv
import numpy as np
import pandas as pd
from matplotlib.pyplot import figure

# %%
def as_num(x):
    y='{:.2f}'.format(x)
    return(y)

# %%
x = []
y = []
with open('/Users/jifeng/Desktop/dog-breed-identification/dog-breed-classification/result/training_progress_ResNet-50.txt','r') as csvfile:
    plots = csv.reader(csvfile, delimiter=' ')
    index = 0
    for row in plots:
        x.append(index)
        train_accuracy = float(row[1])
        y.append(as_num(train_accuracy))
        index = index + 1

fig, ax = plt.subplots()
ax.plot(x, y)
ax.set(xlabel='epoch', ylabel='accuracy',
       title='Training accuracy')
ax.grid()

plt.gcf().set_size_inches(15, 10)

fig.savefig("/Users/jifeng/Desktop/dog-breed-identification/dog-breed-classification/result/image/Training accuracy.png")
plt.show()

# %%
x = []
y = []
with open('/Users/jifeng/Desktop/dog-breed-identification/dog-breed-classification/result/training_progress_ResNet-50.txt','r') as csvfile:
    plots = csv.reader(csvfile, delimiter=' ')
    index = 0
    for row in plots:
        x.append(index)
        val_accuracy = float(row[3])
        y.append(as_num(val_accuracy))
        index = index + 1

fig, ax = plt.subplots()
ax.plot(x, y)
ax.set(xlabel='epoch', ylabel='accuracy',
       title='Validation accuracy')
ax.grid()

plt.gcf().set_size_inches(15, 10)

fig.savefig("/Users/jifeng/Desktop/dog-breed-identification/dog-breed-classification/result/image/Validation accuracy.png")
plt.show()

# %%
x = []
y = []
with open('/Users/jifeng/Desktop/dog-breed-identification/dog-breed-classification/result/training_progress_ResNet-50.txt','r') as csvfile:
    plots = csv.reader(csvfile, delimiter=' ')
    index = 0
    for row in plots:
        x.append(index)
        train_loss = float(row[0])
        y.append(as_num(train_loss))
        index = index + 1

fig, ax = plt.subplots()
ax.plot(x, y)
ax.set(xlabel='epoch', ylabel='loss',
       title='Training loss')
ax.grid()

plt.gca().invert_yaxis() 
plt.gcf().set_size_inches(15, 10)

fig.savefig("/Users/jifeng/Desktop/dog-breed-identification/dog-breed-classification/result/image/Training loss.png")
plt.show()

# %%
x = []
y = []
with open('/Users/jifeng/Desktop/dog-breed-identification/dog-breed-classification/result/training_progress_ResNet-50.txt','r') as csvfile:
    plots = csv.reader(csvfile, delimiter=' ')
    index = 0
    for row in plots:
        x.append(index)
        val_loss = float(row[2])
        y.append(as_num(val_loss))
        index = index + 1

fig, ax = plt.subplots()
ax.plot(x, y)
ax.set(xlabel='epoch', ylabel='loss',
       title='Validation loss')
ax.grid()

plt.gca().invert_yaxis() 
plt.gcf().set_size_inches(15, 10)

fig.savefig("/Users/jifeng/Desktop/dog-breed-identification/dog-breed-classification/result/image/Validation loss.png")
plt.show()

# %%
epoch = []
epoch_val = []
train_loss = []
val_loss = []
with open('/Users/jifeng/Desktop/dog-breed-identification/dog-breed-classification/result/training_progress_ResNet-50.txt','r') as csvfile:
    plots = csv.reader(csvfile, delimiter=' ')
    index = 0
    for row in plots:
        epoch.append(index)
        train = float(row[0])
        train_loss.append(as_num(train))
        index = index + 1
    
with open('/Users/jifeng/Desktop/dog-breed-identification/dog-breed-classification/result/training_progress_ResNet-50.txt','r') as csvfile:
    plots = csv.reader(csvfile, delimiter=' ')    
    index_val = 0
    for row in plots:
        epoch_val.append(index_val)
        val = float(row[2])
        val_loss.append(as_num(val))
        index_val = index_val + 1

print(index)
print(index_val)
# fig, ax = plt.subplots()

# ax.plot(epoch, val_loss)
# ax.plot(epoch, train_loss)
# ax.set(xlabel='epoch', ylabel='loss',
#        title='Loss')
# ax.grid()

plt.figure(figsize=(15,10))
plt.plot(epoch, train_loss)
plt.plot(epoch_val, val_loss)

plt.gca().invert_yaxis() 
plt.gcf().set_size_inches(15, 10)

fig.savefig("/Users/jifeng/Desktop/dog-breed-identification/dog-breed-classification/result/image/Loss.png")
plt.show()
# Out:
# 200
# 200
